# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/Fall2024/blob/main/Thegiver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown **Title: The giver
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("uxFJvlWqphM", width=600)
display(video)
